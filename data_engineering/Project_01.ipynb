# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('movies_complete.csv', parse_dates = ['release_date'])

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
# id                       44691 non-null int64
# title                    44691 non-null object
# tagline                  20284 non-null object
# release_date             44657 non-null datetime64[ns]
# genres                   42586 non-null object
# belongs_to_collection    4463 non-null object
# original_language        44681 non-null object
# budget_musd              8854 non-null float64
# revenue_musd             7385 non-null float64
# production_companies     33356 non-null object
# production_countries     38835 non-null object
# vote_count               44691 non-null float64
# vote_average             42077 non-null float64
# popularity               44691 non-null float64
# runtime                  43179 non-null float64
# overview                 43740 non-null object
# spoken_languages         41094 non-null object
# ...

# %%
df.hist(figsize = (20,12), bins = 100)
plt.show()

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
def filter_func(df, filter, x, min_bud = 0, min_count = 0):
    x = df.loc[(df['budget_musd']>= min_bud) & (df['vote_count'] >= min_count)].sort_values(filter, ascending = x).head(5).copy()
    return x[['id','title', filter]]
filter_func(df, 'revenue_musd', False)
# Out:
#            id                         title  revenue_musd
# 14448   19995                        Avatar       2787.97
# 26265  140607  Star Wars: The Force Awakens       2068.22
# 1620      597                       Titanic       1845.03
# 17669   24428                  The Avengers       1519.56
# 24812  135397                Jurassic World       1513.53

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
filter_func(df, 'budget_musd', False)
# Out:
#           id                                        title  budget_musd
# 16986   1865  Pirates of the Caribbean: On Stranger Tides       380.00
# 11743    285     Pirates of the Caribbean: At World's End       300.00
# 26268  99861                      Avengers: Age of Ultron       280.00
# 10985   1452                             Superman Returns       270.00
# 18517  49529                                  John Carter       260.00

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
df['profit'] = df['revenue_musd'].sub(df['budget_musd'])

filter_func(df, 'profit', False)
# Out:
#            id                         title  profit
# 14448   19995                        Avatar 2550.97
# 26265  140607  Star Wars: The Force Awakens 1823.22
# 1620      597                       Titanic 1645.03
# 24812  135397                Jurassic World 1363.53
# 28501  168259                     Furious 7 1316.25

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
filter_func(df, 'profit', True)
# Out:
#            id                                        title  profit
# 20959   57201                              The Lone Ranger -165.71
# 7164    10733                                    The Alamo -119.18
# 16659   50321                              Mars Needs Moms -111.01
# 43611  339964  Valerian and the City of a Thousand Planets -107.45
# 2684     1911                             The 13th Warrior  -98.30

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df['ROI'] = df['revenue_musd'].div(df['budget_musd'])

filter_func(df, 'ROI', False, min_bud = 10)
# Out:
#           id                       title   ROI
# 1055     601  E.T. the Extra-Terrestrial 75.52
# 255       11                   Star Wars 70.49
# 588      114                Pretty Woman 33.07
# 18300  77338            The Intouchables 32.81
# 1144    1891     The Empire Strikes Back 29.91

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
filter_func(df_budget, 'ROI', True)
# Out:
#           id            title  ROI
# 6955   14844  Chasing Liberty 0.00
# 8041   18475      The Cookout 0.00
# 17381  33927         Deadfall 0.00
# 6678   10944       In the Cut 0.00
# 20015  98339    The Samaritan 0.00

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
filter_func(df, 'vote_count', False)
# Out:
#            id            title  vote_count
# 15368   27205        Inception    14075.00
# 12396     155  The Dark Knight    12269.00
# 14448   19995           Avatar    12114.00
# 17669   24428     The Avengers    12000.00
# 26272  293660         Deadpool    11444.00

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df_votes = df[df['vote_count'] > 10]
filter_func(df, 'vote_average', False, min_count = 10)
# Out:
#            id                        title  vote_average
# 10233   19404  Dilwale Dulhania Le Jayenge          9.10
# 2716    24128            Stop Making Sense          8.70
# 32987  359364                        Human          8.60
# 42792   38794                  Tosun Pasha          8.60
# 313       278     The Shawshank Redemption          8.50

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
filter_func(df, 'vote_average', True, min_count = 10)
# Out:
#            id                           title  vote_average
# 41602  398818            Call Me by Your Name          0.00
# 30618  279988  Extinction: Nature Has Evolved          0.00
# 31486   86215                       The Cloth          1.90
# 8538    22293        Manos: The Hands of Fate          2.00
# 21340   27711                         Killjoy          2.20

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
filter_func(df, 'popularity', False)
# Out:
#            id                 title  popularity
# 30330  211672               Minions      547.49
# 32927  297762          Wonder Woman      294.34
# 41556  321612  Beauty and the Beast      287.25
# 42940  339403           Baby Driver      228.03
# 24187  177572            Big Hero 6      213.85

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
df.columns
df.original_language
# Out:
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
#          ..
# 44686    fa
# 44687    tl
# 44688    en
# 44689    en
# 44690    en
# Name: original_language, Length: 44691, dtype: object

# %%
genres = df.genres.str.contains('Action') | df.genres.str.contains('Science Fiction')
actor = df.cast.str.contains('Bruce')
actress = df.cast.str.contains('Uma Thurma')
director = df.director.str.contains('Quentin Tarantino')
pixar = df.production_companies.str.contains('Pixar')
year = df.release_date.between('2010-01-01', '2015-01-01')
genres_2 = df.genres.str.contains('Action') | df.genres.str.contains('Thriller')
language = df.original_language == 'en'
rating = df.vote_average > 7.5

# %%
df.loc[genres & actor,['id', 'title', 'vote_average']].fillna(0).sort_values('vote_average', ascending = False)
# Out:
#            id                     title  vote_average
# 44431  412669          First Round Down         10.00
# 39083   84275    The Dragon Lives Again         10.00
# 12396     155           The Dark Knight          8.30
# 1144     1891   The Empire Strikes Back          8.20
# 32179   28646                   Spoiler          8.00
# ...       ...                       ...           ...
# 27064   61855         The Painted Hills          2.00
# 30920   42477            Brain of Blood          1.00
# 26620  112141              Menno's Mind          0.00
# 43929  134201               Out of Time          0.00
# 37605   99846  Moonshine County Express          0.00
#
# [384 rows x 3 columns]

# %%
df.loc[actress & director, ['id', 'title', 'runtime']].fillna(0).sort_values('runtime', ascending = False)
# Out:
#        id              title  runtime
# 291   680       Pulp Fiction   154.00
# 7208  393  Kill Bill: Vol. 2   136.00
# 6667   24  Kill Bill: Vol. 1   111.00

# %%
df.loc[pixar & year, ['id', 'title', 'release_date', 'revenue_musd']].fillna(0).sort_values('revenue_musd', ascending = False)
# Out:
#            id                       title release_date  revenue_musd
# 15236   10193                 Toy Story 3   2010-06-16       1066.97
# 20888   62211         Monsters University   2013-06-20        743.56
# 17220   49013                      Cars 2   2011-06-11        559.85
# 18900   62177                       Brave   2012-06-21        538.98
# 16392   40619                 Day & Night   2010-06-17          0.00
# 21694  200481           The Blue Umbrella   2013-02-12          0.00
# 21697  213121        Toy Story of Terror!   2013-10-15          0.00
# 22489   83564                     La luna   2011-01-01          0.00
# 24252   77887           Hawaiian Vacation   2011-06-16          0.00
# 24254   82424                   Small Fry   2011-11-23          0.00
# 25515  130925             Partysaurus Rex   2012-09-14          0.00
# 25516  141423        The Legend of Mor'du   2012-01-01          0.00
# 25517  256835  Toy Story That Time Forgot   2014-12-02          0.00
# ...

# %%
df.loc[genres_2 & language & rating, ['id', 'title', 'release_date', 'vote_average']].sort_values('release_date', ascending = False)
# Out:
#            id                           title release_date  vote_average
# 42624  382614               The Book of Henry   2017-06-16          7.60
# 26273  283995  Guardians of the Galaxy Vol. 2   2017-04-19          7.60
# 43467  416445                     Revengeance   2017-04-05          8.00
# 44431  412669                First Round Down   2017-03-04         10.00
# 41506  263115                           Logan   2017-02-28          7.60
# ...       ...                             ...          ...           ...
# 2230      244                       King Kong   1933-04-07          7.70
# 25954  117004                     Night Court   1932-06-04          8.00
# 8255    25768             Steamboat Bill, Jr.   1928-02-14          7.90
# 2879      961                     The General   1926-12-31          8.00
# 34547  128899        Bardelys the Magnificent   1926-09-30          8.00
#
# [223 rows x 4 columns]

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df['collection'] = np.where(df['belongs_to_collection'].isnull(), 0,1)
df.collection.value_counts()
# Out:
# 0    40228
# 1     4463
# Name: collection, dtype: int64

# %%
df.groupby('collection').mean()['revenue_musd']

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df.groupby('collection').median()[['ROI', 'profit']]
# Out:
#             ROI  profit
# collection
# 0          1.62    5.00
# 1          3.71   64.23

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby('collection').mean()['budget_musd']
# Out:
# collection
# 0   18.05
# 1   38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby('collection').mean()['popularity']
# Out:
# collection
# 0   2.59
# 1   6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby('collection').mean()['vote_average']
# Out:
# collection
# 0   6.01
# 1   5.96
# Name: vote_average, dtype: float64

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.groupby('belongs_to_collection').count().sort_values('id', ascending = False)
# Out:
#                                             id  title  tagline  release_date  \
# belongs_to_collection
# The Bowery Boys                             29     29       24            29
# Totò Collection                             27     27        2            27
# James Bond Collection                       26     26       26            26
# Zatôichi: The Blind Swordsman               26     26        1            26
# The Carry On Collection                     25     25       18            25
# ...                                         ..    ...      ...           ...
# Göta kanal collection                        1      1        0             1
# Hailey Dean Mystery Collection               1      1        0             1
# The Adventures of Mickey Matson Collection   1      1        0             1
# The 1997 Trilogy                             1      1        0             1
# Flesh Gordon Collection                      1      1        1             1
#
# ...

# %%
df.groupby('belongs_to_collection').sum().sort_values('budget_musd', ascending = False)
df.groupby('belongs_to_collection').mean().sort_values('budget_musd', ascending = False)
# Out:
#                                            id  budget_musd  revenue_musd  \
# belongs_to_collection
# Tangled Collection                   60819.00       260.00        591.79
# The Avengers Collection              62144.50       250.00       1462.48
# Pirates of the Caribbean Collection  33731.20       250.00        904.32
# The Hobbit Collection                76375.33       250.00        978.51
# Man of Steel Collection             129316.50       237.50        768.05
# ...                                       ...          ...           ...
# Параграф 78 - Дилогия                53086.00          nan           nan
# Сказки Чуковского                   198951.00          nan           nan
# Чебурашка и крокодил Гена            79701.00          nan           nan
# 男はつらいよ シリーズ                         213347.00          nan           nan
# 식객 시리즈                               77631.50          nan           nan
#
# ...

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.groupby('director').count().sort_values('id', ascending = False)
# Out:
#                   id  title  tagline  release_date  genres  \
# director
# John Ford         66     66       42            66      65
# Michael Curtiz    65     65       47            65      65
# Werner Herzog     54     54       15            54      54
# Alfred Hitchcock  53     53       35            53      52
# Woody Allen       49     49       23            49      49
# ...               ..    ...      ...           ...     ...
# Jason Zada         1      1        1             1       1
# Jasper James       1      1        1             1       1
# Javier Aguirre     1      1        1             1       1
# Javier Balaguer    1      1        0             1       1
# 진모영                1      1        0             1       1
#
#                   belongs_to_collection  original_language  budget_musd  \
# director
# John Ford                             1                 66           13
# Michael Curtiz                        0                 65            7
# ...

# %%
df.groupby('director').sum().sort_values('revenue_musd', ascending = False)
# Out:
#                        id  budget_musd  revenue_musd  vote_count  \
# director
# Steven Spielberg  1263357      1736.95       9256.62    62266.00
# Peter Jackson      268469      1326.78       6528.24    47571.00
# Michael Bay        941840      1670.00       6437.47    28767.00
# James Cameron      206262       760.05       5900.61    33736.00
# David Yates       1017165      1135.00       5334.56    31056.00
# ...                   ...          ...           ...         ...
# Héctor Olivera     287652         0.00          0.00       20.00
# Hélène Fillières   155890         0.00          0.00       10.00
# Héléna Klotz       126879         0.00          0.00        6.00
# I. Robert Levy       5800         0.00          0.00        1.00
# 진모영                306598         0.00          0.00        6.00
#
#                   vote_average  popularity  runtime  cast_size  crew_size  \
# director
# Steven Spielberg        227.50      429.59  4276.00       1072       1624
# ...

# %%
df.groupby('director').revenue_musd.sum().nlargest(10).plot(kind = 'bar')
plt.title('Most revenue generating directors')
plt.ylabel('revenue')
plt.show()

# %%
df.loc[df.vote_count > 10].groupby('director').mean().sort_values('vote_average', ascending = False)
# Out:
#                         id  budget_musd  revenue_musd  vote_count  \
# director
# Ken Burns         26397.00          nan           nan       15.00
# Leonard Ho        44645.00          nan           nan       19.00
# Derek Frankowski  51299.00          nan           nan       27.00
# Jakob Verbruggen 370722.00          nan           nan       12.00
# Beyoncé Knowles  394269.00          nan           nan       45.00
# ...                    ...          ...           ...         ...
# Justin Price      86215.00         2.00           nan       12.00
# Jerry Warren      31258.00          nan           nan       12.00
# Darren Doane     295884.00          nan           nan       25.00
# René Cardona      13383.00          nan           nan       12.00
# Coleman Francis   22727.00          nan           nan       18.00
#
#                   vote_average  popularity  runtime  cast_size  crew_size  \
# director
# Ken Burns                 9.20        3.43   680.00      15.00       7.00
# ...

# %%
act = df.cast.str.split('|', expand = True)

# %%
act = act.stack().reset_index(level = 1, drop = True).to_frame()

# %%
act.columns = ['Act']

# %%
act = act.merge(df[["title", "revenue_musd", "vote_average", "popularity"]], how = 'left', left_index = True , right_index = True )

# %%
agg = act.loc[act['revenue_musd'] > 10].groupby('Act').agg(total_revenue = ('revenue_musd', 'sum'),
                                                           mean_revenue = ('revenue_musd', 'mean'),
                                                           vote_avg = ('vote_average', 'mean'),
                                                           popularity = ('popularity', 'mean'),
                                                           total_movies = ('Act', 'count'))
agg
# Out:
#                      total_revenue  mean_revenue  vote_avg  popularity  \
# Act
#  Frank Nagai                 42.00         42.00      6.50        6.16
#  Larry Mullen Jr.            22.73         22.73      6.70        0.90
# "Weird Al" Yankovic         195.56         48.89      6.18       10.27
# 'Sister' Carol East          41.33         41.33      5.60       16.78
# 'Wild Bill' Laczko           34.00         34.00      6.90        8.80
# ...                            ...           ...       ...         ...
# 楊凱凱                          83.06         83.06      7.00        6.49
# 薛立方                          84.55         84.55      6.30        2.24
# 許淑嬪                         166.12         83.06      7.00        6.49
# 陳美貞                          83.06         83.06      7.00        6.49
# 高桥一生                        333.11        166.55      7.70       23.40
#
#                      total_movies
# Act
#  Frank Nagai                    1
# ...

# %%
agg.total_revenue.nlargest(10).plot(kind = 'bar')

# %%
agg.loc[agg['total_movies'] > 10].nlargest(20, 'mean_revenue')
# Out:
#                     total_revenue  mean_revenue  vote_avg  popularity  \
# Act
# Warwick Davis            13245.21        735.85      7.17       21.07
# Anthony Daniels           8002.41        727.49      7.13       20.01
# Orlando Bloom             9373.18        669.51      7.09       31.79
# Stan Lee                 19412.83        669.41      6.70       47.77
# Daniel Radcliffe          8373.03        644.08      6.98       22.42
# Tom Felton                8356.65        642.82      7.12       22.11
# Andy Serkis              10248.65        640.54      6.97       34.19
# Luke Evans                8031.93        617.84      6.45       37.70
# Jess Harnell             12234.61        611.73      6.53       15.58
# Ian McKellen             10996.46        578.76      6.83       30.41
# Ava Acres                 6272.30        570.21      6.58       64.05
# Emma Watson               9635.58        566.80      6.76       39.26
# ...

# %%
df.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 44686                Drama|Family
# 44687                       Drama
# 44688       Action|Drama|Thriller
# 44689                         NaN
# 44690                         NaN
# Name: genres, Length: 44691, dtype: object

# %%
genres = df.genres.str.split('|', expand = True)
genres = genres.stack().reset_index(level = 1, drop = True).to_frame()
genres.columns = ['genre']
# Out:
#            genre
# 0      Animation
# 0         Comedy
# 0         Family
# 1      Adventure
# 1        Fantasy
# ...          ...
# 44686     Family
# 44687      Drama
# 44688     Action
# 44688      Drama
# 44688   Thriller
#
# [90225 rows x 1 columns]

# %%
gen = genres.merge(df[["title", "revenue_musd", "vote_average", "popularity", 'release_date']], how = 'left', left_index = True, right_index = True)
gen
# Out:
#            genre                title  revenue_musd  vote_average  popularity  \
# 0      Animation            Toy Story        373.55          7.70       21.95
# 0         Comedy            Toy Story        373.55          7.70       21.95
# 0         Family            Toy Story        373.55          7.70       21.95
# 1      Adventure              Jumanji        262.80          6.90       17.02
# 1        Fantasy              Jumanji        262.80          6.90       17.02
# ...          ...                  ...           ...           ...         ...
# 44686     Family               Subdue           nan          4.00        0.07
# 44687      Drama  Century of Birthing           nan          9.00        0.18
# 44688     Action             Betrayal           nan          3.80        0.90
# 44688      Drama             Betrayal           nan          3.80        0.90
# 44688   Thriller             Betrayal           nan          3.80        0.90
#
#       release_date
# ...

# %%
gen_90s = gen.loc[gen.release_date.between('1990','2000')].groupby('genre').mean().sort_values('popularity', ascending = False)
gen_80s = gen.loc[gen.release_date.between('1980','1990')].groupby('genre').mean().sort_values('popularity', ascending = False)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,12))
ax1 = gen_90s.popularity.nlargest(10).plot(kind = 'bar', title = '1990s')
ax2 = gen_80s.popularity.nlargest(10).plot(kind = 'bar', title = '1980s')

# %%
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027315D2ECC8>,
# ...
#       dtype=object)
