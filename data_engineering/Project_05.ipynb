# %% [markdown]
# # Project 5: Working with Pandas and SQL Databases (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 5 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Creating an SQLite Database

# %% [markdown]
# 1. __Import__ sqlite3 (as sq3) and __create__ a new SQLite Database with the name __"movies.db"__.

# %%
import sqlite3 as sq3
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
con = sq3.connect('movies.db')

# %%
con.execute('SELECT * FROM sqlite_master').fetchall()
# Out:
# []

# %%
con.close()

# %% [markdown]
# ## Loading Data from DataFrames into an SQLite Database

# %% [markdown]
# 2. __Load__ the json file __"some_movies.json"__ and __split__ the dataset into the following __four datasets__ (save each dataset in a Pandas DataFrame).

# %% [markdown]
# __Dataset #1 (Movies)__ with columns ["id", "title", "revenue", "budget", "belongs_to_collection_name", "release_date"]. <br>
# Convert "release_date" to datetime and transform "budget" and "revenue" to Million USD before loading into the Database.

# %% [markdown]
# __Dataset #2 (Votes)__ with columns ["id", "vote_count", "vote_average"].

# %% [markdown]
# __Dataset #3 (Genres)__ with columns ["genre_id", "genre_name", "id"]. <br>

# %% [markdown]
# __Dataset #4 (Prod)__ with columns ["comp_id", "comp_logo_path", "comp_name", "comp_origin_country", "id" ]. <br>

# %%
with open('some_movies.json') as openfile:
    data = json.load(openfile)
df = json_normalize(data)

# %%
genres = json_normalize(data, record_path = ['genres'], meta = ['id', 'title'], record_prefix = 'genre_')
genres.head(5)
# Out:
#    genre_id       genre_name      id              title
# 0        12        Adventure  299534  Avengers: Endgame
# 1       878  Science Fiction  299534  Avengers: Endgame
# 2        28           Action  299534  Avengers: Endgame
# 3        28           Action   19995             Avatar
# 4        12        Adventure   19995             Avatar

# %%
prod = json_normalize(data, record_path = ['production_companies'], meta = ['id', 'title'], record_prefix = 'production_')
prod.head()
# Out:
#    production_id              production_logo_path           production_name  \
# 0            420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png            Marvel Studios
# 1            444  /42UPdZl6B2cFXgNUASR8hSt9mpS.png        Dune Entertainment
# 2            574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png  Lightstorm Entertainment
# 3             25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png          20th Century Fox
# 4            290   /Q8mw2AOQQc8Qg0uNwLWq86DVZv.png           Ingenious Media
#
#   production_origin_country      id              title
# 0                        US  299534  Avengers: Endgame
# 1                        US   19995             Avatar
# 2                        US   19995             Avatar
# 3                        US   19995             Avatar
# 4                        GB   19995             Avatar

# %%
_ = pd.read_json('some_movies.json', orient = 'records')

# %%
df1 = df.loc[:,  ["id", "title", "revenue", "budget", "belongs_to_collection_name", "release_date"]]
df2 = df.loc[:,  ["id", "vote_count", "vote_average"]]
df3 = genres
df4 = prod

# %%
df1.revenue = df1.revenue.div(1000000)
df1.budget = df1.budget.div(1000000)

# %%
df1.head()
# Out:
#        id                         title      revenue  budget  \
# 0  299534             Avengers: Endgame  2797.800564   356.0
# 1   19995                        Avatar  2787.965087   237.0
# 2  140607  Star Wars: The Force Awakens  2068.223624   245.0
# 3  299536        Avengers: Infinity War  2046.239637   300.0
# 4     597                       Titanic  1845.034188   200.0
#
#    belongs_to_collection_name release_date
# 0                         NaN   2019-04-24
# 1                         NaN   2009-12-10
# 2                         NaN   2015-12-15
# 3                         NaN   2018-04-25
# 4                         NaN   1997-11-18

# %% [markdown]
# 3. __Load__ the datasets __into the database__ (each dataset should be a separate table in the database). __Name__ the tables "Movies", "Votes", "Genres", "Prod".

# %%
conn = sq3.connect('movies3.db')

# %%
tables = ['Movies', "Votes", "Genres", "Prod"]
db = [df1, df2,df3,df4]          
for a,b in zip(db, tables):
    a.to_sql(b, conn)

# %% [markdown]
# ## Loading Data from SQLite Databases into DataFrames

# %% [markdown]
# 4. __Load__ the full tables "Movies", "Votes", "Genres", "Prod" from "movies.db" into Pandas (four DataFrames). __Set__ "id" as Index.

# %%
conn.execute('SELECT * FROM sqlite_master').fetchall()
# Out:
# [('table',
#   'Movies',
#   'Movies',
#   2,
#   'CREATE TABLE "Movies" (\n"index" INTEGER,\n  "id" INTEGER,\n  "title" TEXT,\n  "revenue" INTEGER,\n  "budget" INTEGER,\n  "belongs_to_collection_name" REAL,\n  "release_date" TEXT\n)'),
#  ('index',
#   'ix_Movies_index',
#   'Movies',
#   3,
#   'CREATE INDEX "ix_Movies_index"ON "Movies" ("index")'),
#  ('table',
#   'Votes',
#   'Votes',
#   4,
#   'CREATE TABLE "Votes" (\n"index" INTEGER,\n  "id" INTEGER,\n  "vote_count" INTEGER,\n  "vote_average" REAL\n)'),
#  ('index',
#   'ix_Votes_index',
#   'Votes',
#   5,
#   'CREATE INDEX "ix_Votes_index"ON "Votes" ("index")'),
#  ('table',
#   'Genres',
#   'Genres',
#   6,
#   'CREATE TABLE "Genres" (\n"index" INTEGER,\n  "genre_id" INTEGER,\n  "genre_name" TEXT,\n  "id" INTEGER,\n  "title" TEXT\n)'),
#  ('index',
#   'ix_Genres_index',
#   'Genres',
#   7,
#   'CREATE INDEX "ix_Genres_index"ON "Genres" ("index")'),
#  ('table',
#   'Prod',
#   'Prod',
#   8,
#   'CREATE TABLE "Prod" (\n"index" INTEGER,\n  "production_id" INTEGER,\n  "production_logo_path" TEXT,\n  "production_name" TEXT,\n  "production_origin_country" TEXT,\n  "id" INTEGER,\n  "title" TEXT\n)'),
#  ('index',
#   'ix_Prod_index',
#   'Prod',
#   9,
#   'CREATE INDEX "ix_Prod_index"ON "Prod" ("index")')]

# %%
movies = pd.read_sql("SELECT * FROM Movies", conn, index_col = 'id', parse_dates = ['release_date'])
votes = pd.read_sql('SELECT * FROM Votes', conn,index_col = 'id')
genres = pd.read_sql("SELECT * FROM Genres", conn, index_col = 'id')
prod = pd.read_sql("SELECT * FROM Prod", conn, index_col = 'id')

# %%
prod.head()
# Out:
#         index  production_id              production_logo_path  \
# id
# 299534      0            420  /hUzeosd33nzE5MCNsZxCGEKTXaQ.png
# 19995       1            444  /42UPdZl6B2cFXgNUASR8hSt9mpS.png
# 19995       2            574  /iB6GjNVHs5hOqcEYt2rcjBqIjki.png
# 19995       3             25  /qZCc1lty5FzX30aOCVRBLzaVmcp.png
# 19995       4            290   /Q8mw2AOQQc8Qg0uNwLWq86DVZv.png
#
#                  production_name production_origin_country              title
# id
# 299534            Marvel Studios                        US  Avengers: Endgame
# 19995         Dune Entertainment                        US             Avatar
# 19995   Lightstorm Entertainment                        US             Avatar
# 19995           20th Century Fox                        US             Avatar
# 19995            Ingenious Media                        GB             Avatar

# %%
conn.close()

# %% [markdown]
# ##  Some Simple SQL Queries

# %% [markdown]
# 5. __Perform__ the following simple __SQL Queries__ and __store__ the results in DataFrames:

# %% [markdown]
# __Load the full "Movies" Table__.

# %%
movies = pd.read_sql('SELECT * FROM Movies', conn, index_col = 'id', parse_dates = ['release_date'])
movies.columns
# Out:
# Index(['index', 'title', 'revenue', 'budget', 'belongs_to_collection_name',
#        'release_date'],
#       dtype='object')

# %%
movies.belongs_to_collection_name.tail()
# Out:
# id
# 330457    None
# 351286    None
# 109445    None
# 321612    None
# 260513    None
# Name: belongs_to_collection_name, dtype: object

# %% [markdown]
# __Load the columns "id", "revenue" and "release_date" from "Movies".__

# %%
movies = pd.read_sql('SELECT id, revenue, release_date FROM Movies', conn)
movies.head()
# Out:
#        id      revenue release_date
# 0  299534  2797.800564   2019-04-24
# 1   19995  2787.965087   2009-12-10
# 2  140607  2068.223624   2015-12-15
# 3  299536  2046.239637   2018-04-25
# 4     597  1845.034188   1997-11-18

# %% [markdown]
# __Get the Total Revenue (sum) over all movies from "Movies".__

# %%
pd.read_sql('SELECT SUM(revenue) FROM Movies', conn)
# Out:
#    SUM(revenue)
# 0  29748.575327

# %% [markdown]
# __Count the number of Movies in "Movies".__

# %%
pd.read_sql('SELECT COUNT(id) FROM Movies', conn)
# Out:
#    COUNT(id)
# 0         18

# %% [markdown]
# __Count the number of Movies that do belong to a collection.__

# %%
pd.read_sql('SELECT COUNT(id) FROM Movies WHERE belongs_to_collection_name <> "None"', conn)
# Out:
#    COUNT(id)
# 0          0

# %%
pd.read_sql('SELECT COUNT(belongs_to_collection_name) FROM Movies', conn)
# Out:
#    COUNT(belongs_to_collection_name)
# 0                                  0

# %% [markdown]
# __Get the average budget from "Movies"__.

# %%
pd.read_sql('SELECT AVG(budget) FROM Movies', conn)
# Out:
#    AVG(budget)
# 0   209.055556

# %% [markdown]
# ## Some more SQL Queries

# %% [markdown]
# 6. __Perform__ the following advanced __SQL Queries__ and __store__ the results in DataFrames:

# %% [markdown]
# __Load all columns for the movie with movie id 597__.

# %%
pd.read_sql('SELECT * FROM Movies WHERE id == 597', conn)
# Out:
#    index   id    title      revenue  budget belongs_to_collection_name  \
# 0      4  597  Titanic  1845.034188   200.0                       None
#
#   release_date
# 0   1997-11-18

# %% [markdown]
# __Load all columns for all movies with a revenue greater than 2000 (MUSD).__

# %%
pd.read_sql('SELECT * FROM Movies WHERE revenue > 2000', conn)
# Out:
#    index      id                         title      revenue  budget  \
# 0      0  299534             Avengers: Endgame  2797.800564   356.0
# 1      1   19995                        Avatar  2787.965087   237.0
# 2      2  140607  Star Wars: The Force Awakens  2068.223624   245.0
# 3      3  299536        Avengers: Infinity War  2046.239637   300.0
#
#   belongs_to_collection_name release_date
# 0                       None   2019-04-24
# 1                       None   2009-12-10
# 2                       None   2015-12-15
# 3                       None   2018-04-25

# %% [markdown]
# __Load all columns for all movies with a revenue greater than 1500 (MUSD) and a budget below 200 (MUSD).__

# %%
pd.read_sql('SELECT * FROM Movies WHERE revenue > 1500 AND budget < 200', conn)
# Out:
#    index      id           title      revenue  budget  \
# 0      5  135397  Jurassic World  1671.713208   150.0
# 1      8  168259       Furious 7  1515.047671   190.0
#
#   belongs_to_collection_name release_date
# 0                       None   2015-06-06
# 1                       None   2015-04-01

# %% [markdown]
# __Get the minimum budget from those movies with a revenue greater than 1250 (MUSD).__

# %%
pd.read_sql('SELECT MIN(budget) FROM Movies WHERE revenue > 1250', conn)
# Out:
#    MIN(budget)
# 0        125.0

# %%
pd.read_sql('SELECT * FROM Movies WHERE revenue > 1250 AND budget == 125', conn)
# Out:
#    index     id                                         title      revenue  \
# 0     11  12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219
#
#    budget belongs_to_collection_name release_date
# 0   125.0                       None   2011-07-07

# %% [markdown]
# __Get all unique collection Names from "Movies".__

# %%
pd.read_sql('SELECT DISTINCT(title) FROM Movies', conn)
# Out:
#                                            title
# 0                              Avengers: Endgame
# 1                                         Avatar
# 2                   Star Wars: The Force Awakens
# 3                         Avengers: Infinity War
# 4                                        Titanic
# 5                                 Jurassic World
# 6                                  The Lion King
# 7                                   The Avengers
# 8                                      Furious 7
# 9                        Avengers: Age of Ultron
# 10                                 Black Panther
# 11  Harry Potter and the Deathly Hallows: Part 2
# 12                      Star Wars: The Last Jedi
# 13                                     Frozen II
# 14                Jurassic World: Fallen Kingdom
# 15                                        Frozen
# 16                          Beauty and the Beast
# 17                                 Incredibles 2

# %% [markdown]
# __Load all movies (all columns) and sort by budget from high to low.__

# %%
pd.read_sql('SELECT * FROM Movies ORDER BY budget DESC', conn)
# Out:
#     index      id                                         title      revenue  \
# 0       0  299534                             Avengers: Endgame  2797.800564
# 1       3  299536                        Avengers: Infinity War  2046.239637
# 2       6  420818                                 The Lion King  1656.943394
# 3       9   99861                       Avengers: Age of Ultron  1405.403694
# 4       2  140607                  Star Wars: The Force Awakens  2068.223624
# 5       1   19995                                        Avatar  2787.965087
# 6       7   24428                                  The Avengers  1519.557910
# 7       4     597                                       Titanic  1845.034188
# 8      10  284054                                 Black Panther  1346.739107
# 9      12  181808                      Star Wars: The Last Jedi  1332.539889
# 10     17  260513                                 Incredibles 2  1241.891456
# 11      8  168259                                     Furious 7  1515.047671
# 12     14  351286                Jurassic World: Fallen Kingdom  1303.459585
# 13     16  321612                          Beauty and the Beast  1263.521126
# 14      5  135397                                Jurassic World  1671.713208
# 15     13  330457                                     Frozen II  1330.764959
# 16     15  109445                                        Frozen  1274.219009
# 17     11   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219
#
#     budget belongs_to_collection_name release_date
# 0    356.0                       None   2019-04-24
# 1    300.0                       None   2018-04-25
# 2    260.0                       None   2019-07-12
# 3    250.0                       None   2015-04-22
# 4    245.0                       None   2015-12-15
# 5    237.0                       None   2009-12-10
# 6    220.0                       None   2012-04-25
# 7    200.0                       None   1997-11-18
# 8    200.0                       None   2018-02-13
# 9    200.0                       None   2017-12-13
# 10   200.0                       None   2018-06-14
# 11   190.0                       None   2015-04-01
# 12   170.0                       None   2018-06-06
# 13   160.0                       None   2017-03-16
# 14   150.0                       None   2015-06-06
# 15   150.0                       None   2019-11-20
# 16   150.0                       None   2013-11-27
# 17   125.0                       None   2011-07-07

# %% [markdown]
# __Load all movies (all columns) that do not belong to a collection.__

# %%
pd.read_sql('SELECT * FROM Movies WHERE belongs_to_collection_name IS NULL', conn)
# Out:
#     index      id                                         title      revenue  \
# 0       0  299534                             Avengers: Endgame  2797.800564
# 1       1   19995                                        Avatar  2787.965087
# 2       2  140607                  Star Wars: The Force Awakens  2068.223624
# 3       3  299536                        Avengers: Infinity War  2046.239637
# 4       4     597                                       Titanic  1845.034188
# 5       5  135397                                Jurassic World  1671.713208
# 6       6  420818                                 The Lion King  1656.943394
# 7       7   24428                                  The Avengers  1519.557910
# 8       8  168259                                     Furious 7  1515.047671
# 9       9   99861                       Avengers: Age of Ultron  1405.403694
# 10     10  284054                                 Black Panther  1346.739107
# 11     11   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219
# 12     12  181808                      Star Wars: The Last Jedi  1332.539889
# 13     13  330457                                     Frozen II  1330.764959
# 14     14  351286                Jurassic World: Fallen Kingdom  1303.459585
# 15     15  109445                                        Frozen  1274.219009
# 16     16  321612                          Beauty and the Beast  1263.521126
# 17     17  260513                                 Incredibles 2  1241.891456
#
#     budget belongs_to_collection_name release_date
# 0    356.0                       None   2019-04-24
# 1    237.0                       None   2009-12-10
# 2    245.0                       None   2015-12-15
# 3    300.0                       None   2018-04-25
# 4    200.0                       None   1997-11-18
# 5    150.0                       None   2015-06-06
# 6    260.0                       None   2019-07-12
# 7    220.0                       None   2012-04-25
# 8    190.0                       None   2015-04-01
# 9    250.0                       None   2015-04-22
# 10   200.0                       None   2018-02-13
# 11   125.0                       None   2011-07-07
# 12   200.0                       None   2017-12-13
# 13   150.0                       None   2019-11-20
# 14   170.0                       None   2018-06-06
# 15   150.0                       None   2013-11-27
# 16   160.0                       None   2017-03-16
# 17   200.0                       None   2018-06-14

# %% [markdown]
# __Load all movies (all columns) that belong to a collection.__

# %%
pd.read_sql('SELECT * FROM Movies WHERE belongs_to_collection_name IS NOT NULL', conn)
# Out:
# Empty DataFrame
# Columns: [index, id, title, revenue, budget, belongs_to_collection_name, release_date]
# Index: []

# %% [markdown]
# __Load all movies (all columns) where "Avengers..." is in the title__.

# %%
pd.read_sql('SELECT * FROM Movies WHERE title LIKE "Avengers%"', conn)
# Out:
#    index      id                    title      revenue  budget  \
# 0      0  299534        Avengers: Endgame  2797.800564   356.0
# 1      3  299536   Avengers: Infinity War  2046.239637   300.0
# 2      9   99861  Avengers: Age of Ultron  1405.403694   250.0
#
#   belongs_to_collection_name release_date
# 0                       None   2019-04-24
# 1                       None   2018-04-25
# 2                       None   2015-04-22

# %% [markdown]
# ## Join Queries

# %% [markdown]
# 7. __Perform__ the following __SQL Join Queries__ and __store__ the results in DataFrames:

# %% [markdown]
# __Join "Movies" and "Votes"__ (all columns).

# %%
pd.read_sql('SELECT * FROM Movies INNER JOIN Votes ON Movies.id = Votes.id', conn)
# Out:
#     index      id                                         title      revenue  \
# 0       0  299534                             Avengers: Endgame  2797.800564
# 1       1   19995                                        Avatar  2787.965087
# 2       2  140607                  Star Wars: The Force Awakens  2068.223624
# 3       3  299536                        Avengers: Infinity War  2046.239637
# 4       4     597                                       Titanic  1845.034188
# 5       5  135397                                Jurassic World  1671.713208
# 6       6  420818                                 The Lion King  1656.943394
# 7       7   24428                                  The Avengers  1519.557910
# 8       8  168259                                     Furious 7  1515.047671
# 9       9   99861                       Avengers: Age of Ultron  1405.403694
# 10     10  284054                                 Black Panther  1346.739107
# 11     11   12445  Harry Potter and the Deathly Hallows: Part 2  1341.511219
# 12     12  181808                      Star Wars: The Last Jedi  1332.539889
# 13     13  330457                                     Frozen II  1330.764959
# 14     14  351286                Jurassic World: Fallen Kingdom  1303.459585
# 15     15  109445                                        Frozen  1274.219009
# 16     16  321612                          Beauty and the Beast  1263.521126
# 17     17  260513                                 Incredibles 2  1241.891456
#
#     budget belongs_to_collection_name release_date  index      id  vote_count  \
# 0    356.0                       None   2019-04-24      0  299534       12607
# 1    237.0                       None   2009-12-10      1   19995       21000
# 2    245.0                       None   2015-12-15      2  140607       14205
# 3    300.0                       None   2018-04-25      3  299536       17718
# 4    200.0                       None   1997-11-18      4     597       16661
# 5    150.0                       None   2015-06-06      5  135397       15399
# 6    260.0                       None   2019-07-12      6  420818        5425
# 7    220.0                       None   2012-04-25      7   24428       22101
# 8    190.0                       None   2015-04-01      8  168259        7359
# 9    250.0                       None   2015-04-22      9   99861       15548
# 10   200.0                       None   2018-02-13     10  284054       14830
# 11   125.0                       None   2011-07-07     11   12445       13447
# 12   200.0                       None   2017-12-13     12  181808       10304
# 13   150.0                       None   2019-11-20     13  330457        3982
# 14   170.0                       None   2018-06-06     14  351286        7337
# 15   150.0                       None   2013-11-27     15  109445       11616
# 16   160.0                       None   2017-03-16     16  321612       12203
# 17   200.0                       None   2018-06-14     17  260513        8147
#
#     vote_average
# 0            8.3
# 1            7.4
# 2            7.4
# 3            8.3
# 4            7.8
# 5            6.6
# 6            7.2
# 7            7.7
# 8            7.3
# 9            7.3
# 10           7.4
# 11           8.1
# 12           7.0
# 13           7.2
# 14           6.5
# 15           7.3
# 16           6.9
# 17           7.5

# %% [markdown]
# __Join "Movies" and "Votes" (only the columns "id", "title", "vote_average").__

# %%
pd.read_sql('SELECT Movies.id, Movies.title, Votes.vote_average FROM Votes INNER JOIN Movies ON Votes.id = Movies.id', conn)
# Out:
#         id                                         title  vote_average
# 0   299534                             Avengers: Endgame           8.3
# 1    19995                                        Avatar           7.4
# 2   140607                  Star Wars: The Force Awakens           7.4
# 3   299536                        Avengers: Infinity War           8.3
# 4      597                                       Titanic           7.8
# 5   135397                                Jurassic World           6.6
# 6   420818                                 The Lion King           7.2
# 7    24428                                  The Avengers           7.7
# 8   168259                                     Furious 7           7.3
# 9    99861                       Avengers: Age of Ultron           7.3
# 10  284054                                 Black Panther           7.4
# 11   12445  Harry Potter and the Deathly Hallows: Part 2           8.1
# 12  181808                      Star Wars: The Last Jedi           7.0
# 13  330457                                     Frozen II           7.2
# 14  351286                Jurassic World: Fallen Kingdom           6.5
# 15  109445                                        Frozen           7.3
# 16  321612                          Beauty and the Beast           6.9
# 17  260513                                 Incredibles 2           7.5

# %% [markdown]
# __Join "Movies" and "Votes" (only the columns "id", "title", "vote_average") and return only those movies with vote_average > 8.__

# %%
pd.read_sql('SELECT Movies.id, Movies.title, Votes.vote_average \
            FROM Movies \
            JOIN Votes \
            ON Movies.id = Votes.id \
            WHERE Votes.vote_average > 8', conn, index_col = 'id')
# Out:
#                                                title  vote_average
# id
# 299534                             Avengers: Endgame           8.3
# 299536                        Avengers: Infinity War           8.3
# 12445   Harry Potter and the Deathly Hallows: Part 2           8.1

# %% [markdown]
# __Join "Movies" and "Votes" (only the columns "id", "title", "vote_average") and return only those movies with vote_average > 8 and in ascending budget order__.

# %%
pd.read_sql('SELECT Movies.id, Movies.title, Votes.vote_average \
            FROM Movies \
            JOIN Votes \
            ON Movies.id = Votes.id \
            WHERE Votes.vote_average > 8 \
            ORDER BY budget ASC', conn, index_col = 'id')
# Out:
#                                                title  vote_average
# id
# 12445   Harry Potter and the Deathly Hallows: Part 2           8.1
# 299536                        Avengers: Infinity War           8.3
# 299534                             Avengers: Endgame           8.3

# %% [markdown]
# ## Final Case Study

# %% [markdown]
# 8. __Perform__ the following advanced __SQL Queries__ and __store__ the results in DataFrames:

# %% [markdown]
# __Get the Total Revenue (sum) for each Production Company.__

# %%
pd.read_sql('SELECT Prod.production_name, Movies.revenue, Movies.id \
                 FROM Prod INNER JOIN Movies \
                 ON Movies.id = Prod.id \
                 GROUP BY Prod.production_name \
                 ORDER BY revenue DESC', conn)
# Out:
#                                 production_name      revenue      id
# 0                                Marvel Studios  2797.800564  299534
# 1                      Lightstorm Entertainment  2787.965087   19995
# 2                               Ingenious Media  2787.965087   19995
# 3                            Dune Entertainment  2787.965087   19995
# 4                              20th Century Fox  2787.965087   19995
# 5                         Truenorth Productions  2068.223624  140607
# 6                                     Lucasfilm  2068.223624  140607
# 7                                     Bad Robot  2068.223624  140607
# 8                                     Paramount  1845.034188     597
# 9                            Universal Pictures  1671.713208  135397
# 10                 The Kennedy/Marshall Company  1671.713208  135397
# 11                      Legendary Entertainment  1671.713208  135397
# 12                      Fuji Television Network  1671.713208  135397
# 13                                       Dentsu  1671.713208  135397
# 14                         Amblin Entertainment  1671.713208  135397
# 15                         Walt Disney Pictures  1656.943394  420818
# 16                       Fairview Entertainment  1656.943394  420818
# 17        Québec Production Services Tax Credit  1515.047671  168259
# 18                                Original Film  1515.047671  168259
# 19                                     One Race  1515.047671  168259
# 20                         Media Rights Capital  1515.047671  168259
# 21  Colorado Office of Film, Television & Media  1515.047671  168259
# 22                               China Film Co.  1515.047671  168259
# 23                    Abu Dhabi Film Commission  1515.047671  168259
# 24                        Warner Bros. Pictures  1341.511219   12445
# 25                                 Heyday Films  1341.511219   12445
# 26                      Ram Bergman Productions  1332.539889  181808
# 27                Walt Disney Animation Studios  1330.764959  330457
# 28                       Perfect World Pictures  1303.459585  351286
# 29                             Mandeville Films  1263.521126  321612
# 30                                        Pixar  1241.891456  260513

# %%
df = pd.read_sql('SELECT Prod.production_name, Movies.revenue, Movies.id, Movies.title \
                 FROM Prod INNER JOIN Movies \
                 ON Movies.id = Prod.id', conn)
df.set_index('id', inplace = True)
df.groupby('production_name').sum().sort_values('revenue', ascending = False)
# Out:
#                                                  revenue
# production_name
# Walt Disney Pictures                         9446.618940
# Marvel Studios                               9115.740912
# 20th Century Fox                             4632.999275
# Lightstorm Entertainment                     4632.999275
# Universal Pictures                           4490.220464
# Lucasfilm                                    3400.763513
# Paramount                                    3364.592098
# Fuji Television Network                      3186.760879
# Dentsu                                       3186.760879
# Legendary Entertainment                      2975.172793
# Amblin Entertainment                         2975.172793
# Ingenious Media                              2787.965087
# Dune Entertainment                           2787.965087
# Walt Disney Animation Studios                2604.983968
# Bad Robot                                    2068.223624
# Truenorth Productions                        2068.223624
# The Kennedy/Marshall Company                 1671.713208
# Fairview Entertainment                       1656.943394
# Colorado Office of Film, Television & Media  1515.047671
# Abu Dhabi Film Commission                    1515.047671
# China Film Co.                               1515.047671
# Media Rights Capital                         1515.047671
# One Race                                     1515.047671
# Original Film                                1515.047671
# Québec Production Services Tax Credit        1515.047671
# Warner Bros. Pictures                        1341.511219
# Heyday Films                                 1341.511219
# Ram Bergman Productions                      1332.539889
# Perfect World Pictures                       1303.459585
# Mandeville Films                             1263.521126
# Pixar                                        1241.891456

# %% [markdown]
# __Get all Production Companies for the movie "Titanic".__

# %%
pd.read_sql('SELECT Prod.production_name, Movies.title, Movies.id \
             FROM Prod INNER JOIN Movies \
             WHERE Movies.title LIKE "Titanic%"', conn)
# Out:
#                                 production_name    title   id
# 0                                Marvel Studios  Titanic  597
# 1                            Dune Entertainment  Titanic  597
# 2                      Lightstorm Entertainment  Titanic  597
# 3                              20th Century Fox  Titanic  597
# 4                               Ingenious Media  Titanic  597
# 5                         Truenorth Productions  Titanic  597
# 6                                     Lucasfilm  Titanic  597
# 7                                     Bad Robot  Titanic  597
# 8                                Marvel Studios  Titanic  597
# 9                                     Paramount  Titanic  597
# 10                     Lightstorm Entertainment  Titanic  597
# 11                             20th Century Fox  Titanic  597
# 12                      Fuji Television Network  Titanic  597
# 13                         Amblin Entertainment  Titanic  597
# 14                      Legendary Entertainment  Titanic  597
# 15                           Universal Pictures  Titanic  597
# 16                                       Dentsu  Titanic  597
# 17                 The Kennedy/Marshall Company  Titanic  597
# 18                         Walt Disney Pictures  Titanic  597
# 19                       Fairview Entertainment  Titanic  597
# 20                               Marvel Studios  Titanic  597
# 21                                    Paramount  Titanic  597
# 22                    Abu Dhabi Film Commission  Titanic  597
# 23                           Universal Pictures  Titanic  597
# 24                               China Film Co.  Titanic  597
# 25                                Original Film  Titanic  597
# 26                      Fuji Television Network  Titanic  597
# 27        Québec Production Services Tax Credit  Titanic  597
# 28  Colorado Office of Film, Television & Media  Titanic  597
# 29                                       Dentsu  Titanic  597
# 30                         Media Rights Capital  Titanic  597
# 31                                     One Race  Titanic  597
# 32                               Marvel Studios  Titanic  597
# 33                               Marvel Studios  Titanic  597
# 34                         Walt Disney Pictures  Titanic  597
# 35                        Warner Bros. Pictures  Titanic  597
# 36                                 Heyday Films  Titanic  597
# 37                                    Lucasfilm  Titanic  597
# 38                      Ram Bergman Productions  Titanic  597
# 39                         Walt Disney Pictures  Titanic  597
# 40                Walt Disney Animation Studios  Titanic  597
# 41                         Walt Disney Pictures  Titanic  597
# 42                         Amblin Entertainment  Titanic  597
# 43                      Legendary Entertainment  Titanic  597
# 44                           Universal Pictures  Titanic  597
# 45                       Perfect World Pictures  Titanic  597
# 46                         Walt Disney Pictures  Titanic  597
# 47                Walt Disney Animation Studios  Titanic  597
# 48                         Walt Disney Pictures  Titanic  597
# 49                             Mandeville Films  Titanic  597
# 50                         Walt Disney Pictures  Titanic  597
# 51                                        Pixar  Titanic  597

# %% [markdown]
# __Get the Total Revenue (sum) for each Genre.__

# %%
df = pd.read_sql('SELECT Genres.genre_name, Movies.id, Movies.revenue, Movies.title \
                  FROM Genres INNER JOIN Movies', conn)
df.set_index('id', inplace = True)

df.groupby('genre_name').sum().sort_values('revenue', ascending = False)
# Out:
#                        revenue
# genre_name
# Adventure        446228.629905
# Action           356982.903924
# Science Fiction  297485.753270
# Family           148742.876635
# Fantasy          148742.876635
# Animation         89245.725981
# Romance           59497.150654
# Thriller          59497.150654
# Drama             29748.575327

# %% [markdown]
# __Get all Genres for the movie "Frozen II".__

# %%
pd.read_sql('SELECT Genres.genre_name, Movies.title FROM Genres INNER JOIN Movies ON Movies.id = Genres.id WHERE Movies.title = "Frozen II"', conn)
# Out:
#   genre_name      title
# 0  Adventure  Frozen II
# 1  Animation  Frozen II
# 2     Family  Frozen II

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %% [markdown]
# # ++++++++++++++++ Hints++++++++++++++++++++

# %% [markdown]
# __Hints for 1.__<br>
# You can do this with sq3.connect("database_name.db")

# %% [markdown]
# __Hints for 2.__ <br>
# You have to use pd.json_normalize(data = ..., record_path = ..., meta = ..., record_prefix = ... ) for Datasets #3 and #4

# %% [markdown]
# __Hints for 3.__<br>
# You can do this with:

# %%
con = sq3.connect("movies.db")
df.to_sql("Table Name", con, index = False)

# %% [markdown]
# __Hints for 4.__<br>
# You can do this with:

# %%
con = sq3.connect("movies.db")
pd.read_sql("SELECT * FROM Table Name", con, index_col = ...)

# %% [markdown]
# __Hints for 5., 6., 7., 8.__<br>
# You can do this with:

# %%
con = sq3.connect("movies.db")
df = pd.read_sql("insert the sql query here", con)
